# %% [markdown]
# ## proposal: use face vector space.
#
# given an target image and wild space
# 1. carve out the face-boxes,
# 2. get the face vector spaces for each image,
# 3. compare vector spaces
#
# Dlibs' deep metric learning algorithm embeds face
# images in some vector space where images of the same person are close to each
# other and images of different people are far apart.

# %% [markdown]
# ### Example output from initial pipeline

# %%
import pandas as pd 
from utils import plot_pair

# %%
example = pd.read_json("output/test_images.json")
example.head(2)
# Out:
#    distance  threshold                                              known  \
# 0  0.000000        0.6  /tf/tendai/match-face/images/test_images/targe...
# 1  0.688545        0.6  /tf/tendai/match-face/images/test_images/targe...
#
#                                              unknown
# 0  /tf/tendai/match-face/images/test_images/wild/...
# 1  /tf/tendai/match-face/images/test_images/wild/...

# %%
for i in range(example.shape[0]):
    plot_pair.plot_sample(example.loc[i]["known"], 
                      example.loc[i]["unknown"], 
                      example.loc[i]["distance"])
